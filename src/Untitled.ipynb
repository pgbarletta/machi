# %%
using Plots, Calculus, Roots, LinearAlgebra

# %% [markdown]
# ## Homework 0

# %%
f(x) = 1/3 * x^3 - x^2 - 3*x + 10
# Out:
# f (generic function with 1 method)

# %%
plot(x -> exp(-x), -4, 4)

# %%
plot(derivative(f), -5, 5)

# %%
find_zeros(g, -4, 4)
# Out:
# 2-element Array{Float64,1}:
#  -0.999999999999925
#   2.9999999999750186

# %%
derivative(derivative(f), 3)
# Out:
# 4.000001758178629

# %%
gg(x, y) = x^2 + y^2
# Out:
# gg (generic function with 1 method)

# %%
x = range(-2,stop=2,length=100)
y = range(sqrt(2),stop=2,length=100)

plot(x, y, gg, st =:surface, camera=(0,-30))

# %%
det([1 , 3] * [-1 , 1]')
# Out:
# 0.0

# %%
A = [[3, .5] [0, 2]]
v = [2, 1]
w = [0, 1]
# Out:
# 2-element Array{Int64,1}:
#  0
#  1

# %%
A*v
# Out:
# 2-element Array{Float64,1}:
#  6.0
#  3.0

# %%
A*[2, 3]
# Out:
# 2-element Array{Float64,1}:
#  6.0
#  7.0

# %%
3*v + 4*w
# Out:
# 2-element Array{Int64,1}:
#  6
#  7

# %%
det(A)
# Out:
# 6.0

# %% [markdown]
# ## Homework 1

# %%
N = 10
x = rand(1:10,N)
y = rand(1:10,N)
u = rand(N)
v = rand(N)
Plots.scatter(x,y)
Plots.quiver!(x,y, quiver=(u,v))

# %%
x = fill(0., 4)
y = fill(0., 4)
u = [-1, 1, -1, -1]
v = [-1, 0, 1.5, 10]
Plots.scatter(x,y, framestyle = :origin)
Plots.quiver!(x,y, quiver=(u,v))

# %%
a = zip(u, v)
# Out:
# zip([-1, 1, -1], [-1.0, 0.0, 1.5])

# %%
for each in a
    println(each)
    println(typeof(each))
end
# Out:
# (-1, -1.0)
# Tuple{Int64,Float64}
# (1, 0.0)
# Tuple{Int64,Float64}
# (-1, 1.5)
# Tuple{Int64,Float64}
